# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split

# %%
data = pd.read_csv('new ads.csv')

# %%
data.head(3)
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0

# %%
data.columns
# Out:
# Index(['TV', 'Radio', 'Newspaper', 'Sales'], dtype='object')

# %%
data.shape
# Out:
# (200, 4)

# %%
data['Sales'].shape
# Out:
# (200,)

# %%
data.plot(kind='scatter', x=['TV'], y='Sales')

data.plot(kind='scatter', x=['Radio'], y='Sales')

data.plot(kind='scatter', x=['Newspaper'], y='Sales')
# Out:
# <Axes: xlabel='[Newspaper]', ylabel='Sales'>

# %%
X = data[['TV','Radio','Newspaper']]
X.head(2)
# Out:
#       TV  Radio  Newspaper
# 0  230.1   37.8       69.2
# 1   44.5   39.3       45.1

# %%
X.shape
# Out:
# (200, 3)

# %%
type(X)
# Out:
# pandas.core.frame.DataFrame

# %%
y = data['Sales']
y.head(2)
# Out:
# 0    22.1
# 1    10.4
# Name: Sales, dtype: float64

# %%
print(y.shape)
# Out:
# (200,)

# %%
print(type(y))
# Out:
# <class 'pandas.core.series.Series'>

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (150, 3)
# (150,)
# (50, 3)
# (50,)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
print(lr.intercept_)
# Out:
# 4.914605320858447

# %%
print(lr.coef_)
# Out:
# [ 0.0553335   0.09754627 -0.00408485]

# %%
y_pred = lr.predict(X_test)

# %%
print(y_pred)
# Out:
# [21.26320379 18.16584023 10.31635846 21.31685441 20.91343842 24.43371305
#  16.81693994 15.73384726 10.21522912 18.90024654 15.86206176 10.66862947
#  19.11947939 15.44297431 17.97799581 15.14596396 13.85554324 21.36527312
#  10.09745828 19.41300015 11.39182772 11.77073759  8.6335414  12.17854643
#  12.70138773 17.0004526   9.76058646 21.23154166 18.22647132 19.73565902
#  22.16171303 17.87557405 16.64616869 14.94944178 21.52242228 17.10437496
#  17.49892219 12.50291861 21.08208199  7.89037952  5.57392063  9.85124942
#   7.03406622 19.22954245  7.89047729 15.31856548 13.66592326 21.07742311
#  20.57724701 20.46129298]

# %%
from sklearn import metrics

# %%
print("MAE:    ", metrics.mean_absolute_error(y_test, y_pred))
print("MSE:    ",metrics.mean_squared_error(y_test, y_pred))
print("RMSE:   ",np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# MAE:     1.2599122648350085
# MSE:     2.339427421895418
# RMSE:    1.5295186896195214
