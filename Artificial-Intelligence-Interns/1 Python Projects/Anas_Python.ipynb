# %%
# Here Below i have created a program, which takes input as tasks from the user and apply these specific operation
tasks = []                                               # Define an empty list to store tasks
def add_task(task):                                      # Creating function for adding task
  tasks.append(task)
  print("Task added:", task)

def view_task():                                         # Creating fucntion for viewing task
  print("To-Do List:")
  for index, task in enumerate(tasks, start=1):
    print(f"{index}. {task}")

def complete_task(index):                                # Creating function for completing task
  if 1<= index <= len(tasks):
    completed_task = tasks.pop(index-1)
    print("Task completed:", completed_task)
  else:
    print("Invalid task index")

def remove_task(index):                                  # Creating function for removing task
   if 1<= index <= len(tasks):
    removed_task = tasks.pop(index-1)
    print("Task removed:", removed_task)
   else:
    print("Invalid task index")

while True:                                              # List of funtions user can operate
    print("\nOptions:")
    print("1. Add Task")
    print("2. View Tasks")
    print("3. Mark Task as Completed")
    print("4. Remove Task")
    print("5. Quit")

    choice = input("Enter your choice: ")                 # Asking user to perform specific task

    if choice=="1":
      task = input("Enter your task: ")
      add_task(task)
    elif choice=="2":
      view_task()
    elif choice=="3":
      index = int(input("Enter the index of task you mark to complete: "))
      complete_task(index)
    elif choice=="4":
      index = int(input("Enter the index of task you want to remove: "))
      remove_task(index)
    elif choice=="5":
      print("Good bye")
      break
    else:
      print("invalid choice choose. Please choose the valid option.")

# %%
# Define empty lists to store tasks and mathematical operations
general_tasks = []
math_operations = ["addition", "subtraction", "multiplication", "division"]

# Function to add a task to the list
def add_task(task):
    general_tasks.append(task)
    print("Task added:", task)

# Function to view the list of tasks
def view_tasks():
    print("To-Do List:")
    for index, task in enumerate(general_tasks, start=1):
        print(f"{index}. {task}")

# Function to mark a task as completed
def complete_task(index):
    if 1 <= index <= len(general_tasks):
        completed_task = general_tasks.pop(index - 1)
        print("Task completed:", completed_task)
    else:
        print("Invalid task index")

# Function to remove a task from the list
def remove_task(index):
    if 1 <= index <= len(general_tasks):
        removed_task = general_tasks.pop(index - 1)
        print("Task removed:", removed_task)
    else:
        print("Invalid task index")

# Main program loop
current_mode = "General Tasks"
while True:
    print("\nOptions:")
    print("1. General Tasks")
    print("2. Mathematical Tasks")
    print("3. Quit")

    user_input = input("Enter your choice: ")

    if user_input == "1":
        print("\nGeneral Tasks:")
        print("a. Add Task")
        print("b. View Tasks")
        print("c. Mark Task as Completed")
        print("d. Remove Task")
        choice = input("Enter your choice: ")

        if choice == "a":
            task = input("Enter your task: ")
            add_task(task)
        elif choice == "b":
            view_tasks()
        elif choice == "c":
            index = int(input("Enter the index of the task to mark as completed: "))
            complete_task(index)
        elif choice == "d":
            index = int(input("Enter the index of the task to remove: "))
            remove_task(index)
        else:
            print("Invalid choice. Please choose a valid option.")

    elif user_input == "2":
        print("\nMathematical Tasks:")
        print("1. Addition")
        print("2. Subtraction")
        print("3. Multiplication")
        print("4. Division")
        choice = input("Enter your choice: ")

        if choice in ["1", "2", "3", "4"]:
            num1 = float(input("Enter the first number: "))
            num2 = float(input("Enter the second number: "))

            if choice == "1":
                print("Result:", num1 + num2)
            elif choice == "2":
                print("Result:", num1 - num2)
            elif choice == "3":
                print("Result:", num1 * num2)
            elif choice == "4":
                if num2 != 0:
                    print("Result:", num1 / num2)
                else:
                    print("Cannot divide by zero.")
            else:
                print("Invalid choice. Please choose a valid option.")
        else:
            print("Invalid choice. Please choose a valid option.")

    elif user_input == "3":
        print("Goodbye!")
        break
    else:
        print("Invalid choice. Please choose a valid option.")
